# %%
# record a video of how your favorite object moves in the front of camera

# %%
# save several snapshots from the video

# %%
# annotate images, using https://www.makesense.ai/ add label / select ROI + label / action / export / yolo

# %%
# create the dataset (zip file), transfer it to colab and unpack

# %%
# train yolo detector and download the exported model

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchsummary import summary

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# %%
# upload your model
from google.colab import files
uploaded = files.upload('your-yolo-model.pth')
modelfile = list(uploaded.keys())[0]
print(modelfile)

# %%
# load the model

# %%
# define the image processing
def process_image(image):
    pass

# %%
# upload your video
uploaded = files.upload('your-video.mp4')
videofile = list(uploaded.keys())[0]
print(videofile)

# %%
# process video
resultfile = 'result.avi'
video = cv2.VideoCapture(videofile)
fps = video.get(cv2.CAP_PROP_FPS)
hasFrame, frame = video.read()
out = cv2.VideoWriter()
out.open(resultfile,cv2.VideoWriter_fourcc('M','J','P','G'),fps,(frame.shape[1],frame.shape[0]))
while True:
    result = process_image(frame)
    out.write(result)
    hasFrame, frame = video.read()
    if not hasFrame:
        break
out.release()

# %%
# download result
files.download(resultfile)

# %%
# submit all notebooks, the dataset and the result video
